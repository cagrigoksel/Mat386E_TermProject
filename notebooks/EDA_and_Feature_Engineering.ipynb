# %%
import pandas as pd

df = pd.read_csv('../data/raw/stock_AAPL_20241104.csv')

df
# Out:
#                           Price           Adj Close               Close  \
# 0                        Ticker                AAPL                AAPL
# 1                          Date                 NaN                 NaN
# 2     2010-01-04 00:00:00+00:00   6.454506874084473   7.643214225769043
# 3     2010-01-05 00:00:00+00:00   6.465665340423584   7.656428813934326
# 4     2010-01-06 00:00:00+00:00   6.362819671630859   7.534643173217773
# ...                         ...                 ...                 ...
# 3731  2024-10-28 00:00:00+00:00  233.39999389648438  233.39999389648438
# 3732  2024-10-29 00:00:00+00:00   233.6699981689453   233.6699981689453
# 3733  2024-10-30 00:00:00+00:00  230.10000610351562  230.10000610351562
# 3734  2024-10-31 00:00:00+00:00  225.91000366210938  225.91000366210938
# 3735  2024-11-01 00:00:00+00:00  222.91000366210938  222.91000366210938
#
#                     High                 Low                Open     Volume
# ...
